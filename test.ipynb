# %%
import dace
import numpy as np

a = np.random.rand(2, 3)
a
# Out:
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"><script>/*! For license information please see sdfv.js.LICENSE.txt */
# ...

# %%
import dace
@dace.program
def func():
    return 1
func.to_sdfg()
# Out:
# global_vars:  ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', 'sys', 'os', '__vsc_ipynb_file__', '_i', '_ii', '_iii', '_i1', 'dace', 'np', 'a', '_1', '_i2', 'builtins', 'numpy']
# Module(body=[FunctionDef(name='func', args=arguments(posonlyargs=[], args=[], kwonlyargs=[], kw_defaults=[], defaults=[]), body=[Return(value=Constant(value=1))], decorator_list=[Attribute(value=Name(id='dace', ctx=Load()), attr='program', ctx=Load())])], type_ignores=[])
# <div id="contents_4863875503261563189" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
# ...

# %%
@dace.program
def func(A):
    if ...:
        return A + A
    else:
        return A - A

func.to_sdfg(a)
# Out:
# global_vars:  ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', 'sys', 'os', '__vsc_ipynb_file__', '_i', '_ii', '_iii', '_i1', 'dace', 'np', 'a', '_1', '_i2', 'func', '_2', '_i3', 'builtins', 'numpy']
# <div id="contents_2584679401763111052" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
# ...

# %%
from random import randint

@dace.program
def main():
    cond = randint(0, 1)
    if cond:
        i = 1
    else:
        i = 7
    a = i
    return a

main.to_sdfg()
# Out:
# global_vars:  ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', 'sys', 'os', '__vsc_ipynb_file__', '_i', '_ii', '_iii', '_i1', 'dace', 'np', 'a', '_1', '_i2', 'func', '_2', '_i3', 'randint', 'builtins', 'numpy']
# ...

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
randint()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/alexanderhammett/Dropbox/ETH Master/_BSc Thesis/Code/dace/test.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alexanderhammett/Dropbox/ETH%20Master/_BSc%20Thesis/Code/dace/test.ipynb#ch0000009?line=0'>1</a> randint()
#
# NameError: name 'randint' is not defined
